# %%
# Importing the required libraries
import numpy as np
import random
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

# %%
import numpy as np
import matplotlib.pyplot as plt

class MazeGenerator:
    def __init__(self, width, height, density):
        self.width = width
        self.height = height
        self.density = density
        self.grid = self.generate_random_maze()

    def generate_random_maze(self):
        maze = np.random.choice([0, 1], size=(self.height, self.width), p=[1-self.density, self.density])
        maze[0, 0] = 0  # Entrance
        maze[-1, -1] = 0  # Exit
        
        
   # Make the entrance and exit
        # Generate a random path from entrance to exit using random walk
        x, y = 0, 0
        while (x, y) != (self.width - 1, self.height - 1):
            directions = [(0, 1), (1, 0)]
            random.shuffle(directions)
            for dx, dy in directions:
                nx, ny = x + dx, y + dy
                if 0 <= nx < self.width and 0 <= ny < self.height:
                    #maze[ny, nx] = 0
                    x, y = nx, ny
                    break        
        
        return maze

    def display(self, start_positions, goal_positions, paths=None, animate=False):
        fig, ax = plt.subplots()
        ax.imshow(self.grid, cmap='binary')

        if isinstance(start_positions, list):
            # Mark the entrance and exit positions for each pair
            for i in range(len(start_positions)):
                ax.scatter(start_positions[i][1], start_positions[i][0], color='red', marker='o', s=50, label='Start')
                ax.scatter(goal_positions[i][1], goal_positions[i][0], color='green', marker='o', s=50, label='Goal')

            if paths and animate:
                # Create a function to update the animation
                def update(frame):
                    ax.clear()
                    ax.imshow(self.grid, cmap='binary')
                    for i in range(len(start_positions)):
                        ax.scatter(start_positions[i][1], start_positions[i][0], color='red', marker='o', s=50, label='Start')
                        ax.scatter(goal_positions[i][1], goal_positions[i][0], color='green', marker='o', s=50, label='Goal')
                        path_x, path_y = zip(*paths[i][:frame+1])
                        ax.plot(path_y, path_x, marker='o', markersize=1, label=f'Path {i+1}')
                        ax.plot(path_y[-1], path_x[-1], color='blue', marker='*', markersize=10)  # Marker on the moving agent
                    #ax.legend()
                    ax.legend().set_visible(False)

                # Create the animation
                ani = FuncAnimation(fig, update, frames=len(paths[0]), interval=500)
                plt.show()
                return ani
        else:
            # Mark the entrance and exit positions
            ax.scatter(start_positions[1], start_positions[0], color='red', marker='o', s=50, label='Start')
            ax.scatter(goal_positions[1], goal_positions[0], color='green', marker='o', s=50, label='Goal')

            if paths and animate:
                # Create a function to update the animation
                print('========test===========')
                def update(frame):
                    ax.clear()
                    ax.imshow(self.grid, cmap='binary')
                    ax.scatter(start_positions[1], start_positions[0], color='red', marker='o', s=50, label='Start')
                    ax.scatter(goal_positions[1], goal_positions[0], color='green', marker='o', s=50, label='Goal')
                    path_x, path_y = zip(*paths[:frame+1])
                    ax.plot(path_y, path_x, marker='o', color='blue', markersize=1, label='Learned Path')
                    ax.plot(path_y[-1], path_x[-1], color='blue', marker='*', markersize=10)  # Marker on the moving agent
                    #ax.legend()
                    ax.legend().set_visible(False)

                # Create the animation
                ani = FuncAnimation(fig, update, frames=len(paths), interval=250)
                plt.show()
                return ani
        plt.legend()
        plt.show()



    # def display(self, start_positions, goal_positions, paths=None):
    #     plt.imshow(self.grid, cmap='binary')

    #     if isinstance(start_positions, list):
    #         # Mark the entrance and exit positions for each pair
    #         for i in range(len(start_positions)):
    #             plt.scatter(start_positions[i][1], start_positions[i][0], color='red', marker='o', s=50, label='Start')
    #             plt.scatter(goal_positions[i][1], goal_positions[i][0], color='green', marker='o', s=50, label='Goal')

    #         if paths:
    #             # Plot the learned paths for each pair
    #             for i in range(len(paths)):
    #                 path_x, path_y = zip(*paths[i])
    #                 plt.plot(path_y, path_x, marker='o', markersize=1, label=f'Path {i+1}')
    #     else:
    #         # Mark the entrance and exit positions
    #         plt.scatter(start_positions[1], start_positions[0], color='red', marker='o', s=50, label='Start')
    #         plt.scatter(goal_positions[1], goal_positions[0], color='green', marker='o', s=50, label='Goal')

    #         if paths:
    #             # Plot the learned path
    #             path_x, path_y = zip(*paths)
    #             plt.plot(path_y, path_x, marker='o', color='blue', markersize=1, label='Learned Path')
    #     plt.legend()
    #     plt.show()

# %%
# Create a maze generator instance
# Define the dimensions of the maze
width = 4
height = 4

# Define the density of walls in the maze (between 0 and 1)
density = 0.05
maze_generator = MazeGenerator(width, height, density)

# %%
# Specify the starting and goal positions
startPos = (0,0)
goalPos = (width-1,height-1)

# Display the generated maze as a figure with starting and goal positions
maze_generator.display(startPos, goalPos)

# %%
import numpy as np

class QLearningMazeSolver:
    def __init__(self, maze, startPos, goalPos, alpha=0.1, gamma=1, epsilon=0.1, epochs=6000):
        self.maze = maze
        self.startPos = startPos
        self.goalPos = goalPos
        self.alpha = alpha  # Learning rate
        self.gamma = gamma  # Discount factor
        self.epsilon = epsilon  # Exploration rate
        self.epochs = epochs  # Number of episodes
        self.height, self.width = maze.shape  # Get maze dimensions
        self.q_table = np.zeros((self.height, self.width, 4))  # Q-table: 4 possible actions (up, down, left, right)
        self.Maxtstep_final = 1000
        self.MAX_STEP = 10000
        


    def greedy_policy(self, state):
        q_values = self.q_table[state[0], state[1]]
        max_q_value = np.max(q_values)
        # Find indices of actions with maximum Q-value
        greedy_actions = [i for i, q_value in enumerate(
            q_values) if q_value == max_q_value]
        # If there are multiple greedy actions, randomly select one
        action = np.random.choice(greedy_actions)
        #action = np.argmax(q_values)
        return action

    def eps_greedy_policy(self, state):
        if np.random.uniform(0, 1) < self.epsilon:
            return np.random.randint(0, 4)  # Random action (exploration)
        else:
            return self.greedy_policy(state)


    def choose_action(self, state):
        return self.eps_greedy_policy(state)

    def update_q_table(self, state, action, reward, next_state):
        self.q_table[state[0], state[1], action] += self.alpha * (reward + self.gamma * np.max(self.q_table[next_state[0], next_state[1]]) - self.q_table[state[0], state[1], action])

    def solve_maze(self):
        episode_steps = []
        for ep in range(self.epochs):
            state = self.startPos
            steps = 0  # Variable to store steps in current episode
            while state != self.goalPos:
                action = self.choose_action(state) # behavior policy
                next_state, reward = self.take_action(state, action)
                self.update_q_table(state, action, reward, next_state)
                state = next_state
                steps = steps + 1
                if steps == self.MAX_STEP:
                    print("Max_Step {} reached".format(self.MAX_STEP))
            if ep % 100 == 0:
                print('episod = {}'.format(ep))
                print('steps = {}'.format(steps))
            episode_steps.append(steps)  # Save total steps for the current episode
                
        return episode_steps

    def take_action(self, state, action):
        actions = [(0, -1), (0, 1), (-1, 0), (1, 0)]  # Possible actions: up, down, left, right
        next_state = (state[0] + actions[action][0], state[1] + actions[action][1])      
        
        # If next position is a wall or outside grid boundaries, set reward to -2
        if next_state[0] == -1 or next_state[0] == self.height  or next_state[1] == -1 or next_state[1] == self.width:
            reward = -2
            next_state = state
        elif self.maze[next_state[0], next_state[1]] == 1:
            reward = -2
            next_state = state            
        elif next_state == self.goalPos:
            reward = 10  # Reward: 10 for reaching the goal
        else:
            reward = -1  # Reward: -1 for every other movement
        
        return next_state, reward


    def get_path(self):
        path = [self.startPos]
        state = self.startPos
        step = 0
        while state != self.goalPos:
            step += 1
            next_state, _ = self.take_action(state, self.greedy_policy(state))
            path.append(next_state)
            state = next_state
            if step == self.Maxtstep_final:
                print("Max_Step {} reached".format(self.Maxtstep_final))
        return path

# Example usage:
solver = QLearningMazeSolver(maze_generator.grid, startPos, goalPos)
episode_steps = solver.solve_maze()
# Out:
# episod = 0
# steps = 798
# episod = 100
# steps = 47
# episod = 200
# steps = 44
# episod = 300
# steps = 28
# episod = 400
# steps = 26
# episod = 500
# steps = 24
# episod = 600
# steps = 27
# episod = 700
# steps = 24
# episod = 800
# steps = 24
# episod = 900
# steps = 24
# episod = 1000
# steps = 25
# episod = 1100
# steps = 27
# episod = 1200
# steps = 24
# episod = 1300
# steps = 22
# episod = 1400
# steps = 24
# episod = 1500
# steps = 23
# episod = 1600
# steps = 30
# episod = 1700
# steps = 24
# episod = 1800
# steps = 24
# episod = 1900
# steps = 26
# episod = 2000
# steps = 26
# episod = 2100
# steps = 24
# episod = 2200
# steps = 26
# episod = 2300
# steps = 25
# episod = 2400
# steps = 25
# episod = 2500
# steps = 22
# episod = 2600
# steps = 24
# episod = 2700
# steps = 25
# episod = 2800
# steps = 23
# episod = 2900
# steps = 22
# episod = 3000
# steps = 24
# episod = 3100
# steps = 24
# episod = 3200
# steps = 22
# episod = 3300
# steps = 22
# episod = 3400
# steps = 22
# episod = 3500
# steps = 28
# episod = 3600
# steps = 22
# episod = 3700
# steps = 26
# episod = 3800
# steps = 22
# episod = 3900
# steps = 23
# episod = 4000
# steps = 27
# episod = 4100
# steps = 22
# episod = 4200
# steps = 24
# episod = 4300
# steps = 22
# episod = 4400
# steps = 24
# episod = 4500
# steps = 24
# episod = 4600
# steps = 27
# episod = 4700
# steps = 23
# episod = 4800
# steps = 24
# episod = 4900
# steps = 24
# episod = 5000
# steps = 22
# episod = 5100
# steps = 22
# episod = 5200
# steps = 22
# episod = 5300
# steps = 24
# episod = 5400
# steps = 22
# episod = 5500
# steps = 27
# episod = 5600
# steps = 27
# episod = 5700
# steps = 22
# episod = 5800
# steps = 22
# episod = 5900
# steps = 22

# %%
plt.plot(episode_steps[0:6000])
plt.xlabel('episode#')
plt.ylabel('steps')
# Out:
# Text(0, 0.5, 'steps')

# %%
path = solver.get_path()
# Display the maze with the learned path
ani = maze_generator.display(startPos, goalPos, path, animate=True)
ani.save('test.gif', writer='pillow')
# Out:
# ========test===========

# %%
class QLearningMazeSolverMultiAgent:
    def __init__(self, maze, startPositions, goalPositions, alpha=0.1, gamma=1, epsilon=0.1, epochs=20000):
        self.maze = maze
        self.startPos = startPositions
        self.goalPos = goalPositions
        self.alpha = alpha  # Learning rate
        self.gamma = gamma  # Discount factor
        self.epsilon = epsilon  # Exploration rate
        self.epochs = epochs  # Number of episodes
        self.height, self.width = maze.shape  # Get maze dimensions
        self.num_agents = len(startPositions)
        self.q_tables = [np.zeros((self.height, self.width, 5)) for _ in range(self.num_agents)]  # Q-tables for each agent
        self.MAX_STEPS = 10000
        self.MAX_STEPS_final = 500


    def greedy_policy(self, state, agent_id):
        q_values = self.q_tables[agent_id][state[0], state[1]]
        max_q_value = np.max(q_values)
        # Find indices of actions with maximum Q-value
        greedy_actions = [i for i, q_value in enumerate(
            q_values) if q_value == max_q_value]
        # If there are multiple greedy actions, randomly select one
        action = np.random.choice(greedy_actions)
        #action = np.argmax(q_values)
        return action

    def eps_greedy_policy(self, state, agent_id, epsilon=None):
        if epsilon:
            eps_greedy = epsilon
        else:
            eps_greedy = self.epsilon
        if np.random.uniform(0, 1) < eps_greedy:
            return np.random.randint(0, 5)  # Random action (exploration)
        else:
            return self.greedy_policy(state, agent_id)


    def choose_action(self, state, agent_id):
        return self.eps_greedy_policy(state, agent_id)

    def update_q_table(self, state, action, reward, next_state, agent_id):
        self.q_tables[agent_id][state[0], state[1], action] += self.alpha * (
            reward + self.gamma * np.max(self.q_tables[agent_id][next_state[0], next_state[1]]) - self.q_tables[agent_id][state[0], state[1], action]
        )

    def solve_maze(self):
        episode_steps = []
        for ep in range(self.epochs):
            total_steps = 0
            agents_at_goals = np.zeros((self.num_agents,1))  # Keep track of agents at their respective goals
            total_steps = 0
            state = self.startPos.copy()
            while total_steps <= self.MAX_STEPS:
                total_steps += 1
                next_state = state.copy()  # Make a copy of the current state
                for agent_id in range(self.num_agents):
                    # Check if the agent reached its goal
                    if state[agent_id] == self.goalPos[agent_id]:
                       agents_at_goals[agent_id] = 1
                    else:
                        action = self.choose_action(state[agent_id], agent_id)
                        next_state, reward = self.take_action(state, action, agent_id)
                        #print('====================')
                        #print(next_state[agent_id])
                        self.update_q_table(state[agent_id], action, reward, next_state[agent_id], agent_id)
                        state = next_state
                                        
                # Check if all agents reached their goals
                if np.sum(agents_at_goals) == len(self.startPos):
                    #print(f"Episode {ep}: All agents reached their goals.")
                    break  # Stop the episode if all agents reached their goals
                    
            if ep % 200 == 0:
                print('episode = {}, total_steps = {}'.format(ep, total_steps))

            episode_steps.append(total_steps)  # Save total steps for the current episode        
                
        return episode_steps

    def take_action(self, state, action, agent_id):
        actions = [(0, -1), (0, 1), (-1, 0), (1, 0), (0,0)]  # Possible actions: up, down, left, right
        next_state = state.copy()
        next_state[agent_id] = (state[agent_id][0] + actions[action][0], state[agent_id][1] + actions[action][1])
        
        # Ensure next state is within grid boundaries
        next_state[agent_id] = (max(0, min(self.height - 1, next_state[agent_id][0])),
                    max(0, min(self.width - 1, next_state[agent_id][1])))        
        
        reward = 0
        # if state[agent_id] == self.goalPos[agent_id]:
        #     if next_state[agent_id] == self.goalPos[agent_id]:
        #         reward += 0
        #     else:
        #         reward += -100
        
        if  self.maze[next_state[agent_id][0], next_state[agent_id][1]] == 1:  # If next position is a wall, keep the next state the same as the current state
            next_state[agent_id] = state[agent_id]
            reward += -1
        elif any(next_state[agent_id] == state[i] for i in range(len(state)) if i != agent_id):
            next_state[agent_id] = state[agent_id]
            reward += -10
        elif next_state[agent_id] == self.goalPos[agent_id]:
            if state[agent_id] == self.goalPos[agent_id]:
                reward += 0
            else:
                reward += 10  # Reward: 10 for reaching the goal
            done = True  # Episode terminates
        else:   
            reward += -1  # Reward: -1 for every movement
            done = False  # Episode continues

        if state[agent_id] == self.goalPos[agent_id]: # do nothing if reach the goal
            reward = 0
            next_state[agent_id] = state[agent_id]
        
        return next_state, reward

    def get_paths(self):
        paths = [[] for _ in range(self.num_agents)]  # Initialize empty paths for each agent
        states = self.startPos[:]  # Initialize states for each agent
        for agent_id in range(self.num_agents):
            paths[agent_id].append(states[agent_id])
        # Continue until all agents reach their goals
        steps = 0
        use_eps_greedy = False
        while not all(state == goal for state, goal in zip(states, self.goalPos)):
            steps += 1
            state_change = np.zeros((self.num_agents,1))
            for agent_id in range(self.num_agents):
                if use_eps_greedy:
                    action = self.eps_greedy_policy(states[agent_id], agent_id)  # Choose action for the agent
                else:
                     action = self.greedy_policy(states[agent_id], agent_id)  # Choose action for the agent
                next_state, _ = self.take_action(states, action, agent_id)  # Take action
                paths[agent_id].append(next_state[agent_id])  # Append next state to the path
                if not next_state[agent_id] == states[agent_id]:
                    state_change[agent_id] = 1
                states = next_state  # Update state for the next iteration

            if np.sum(state_change) == 0:
                use_eps_greedy = False


            if steps == self.MAX_STEPS_final:
                print('max steps reached')
                break
        
        return paths

# %%
# Create a maze generator instance
# Define the dmensions of the maze
width = 16
height = 16

# Define the density of walls in the maze (between 0 and 1)
density = 0.15
maze_generator = MazeGenerator(width, height, density)
# Define start and goal positions for each agent

# %%
startPositions = [(0, 0), (width-1, 0), (width-2, 0), (0, height-3), (0,3), (0,5)]
goalPositions = [(height-1, width-1), (0, height-1), (0, height-2), (height-3,0),(4,11),(6,9)]
# goalPositions = [(4, 4),  (0, height-1), (0, height-2), (height-3,0),(4,11),(6,9)]
maze_generator.display(startPositions, goalPositions)

# %%
# Create an instance of the solver
solver = QLearningMazeSolverMultiAgent(maze_generator.grid, startPositions, goalPositions, epochs=10000)

# Solve the maze
episode_steps = solver.solve_maze()
# Out:
# episode = 0, total_steps = 58
# episode = 200, total_steps = 11
# episode = 400, total_steps = 7
# episode = 600, total_steps = 8
# episode = 800, total_steps = 9
# episode = 1000, total_steps = 10
# episode = 1200, total_steps = 16
# episode = 1400, total_steps = 9
# episode = 1600, total_steps = 7
# episode = 1800, total_steps = 7
# episode = 2000, total_steps = 10
# episode = 2200, total_steps = 12
# episode = 2400, total_steps = 9
# episode = 2600, total_steps = 7
# episode = 2800, total_steps = 7
# episode = 3000, total_steps = 7
# episode = 3200, total_steps = 10
# episode = 3400, total_steps = 8
# episode = 3600, total_steps = 7
# episode = 3800, total_steps = 8
# episode = 4000, total_steps = 7
# episode = 4200, total_steps = 8
# episode = 4400, total_steps = 7
# episode = 4600, total_steps = 12
# episode = 4800, total_steps = 8
# episode = 5000, total_steps = 7
# episode = 5200, total_steps = 7
# episode = 5400, total_steps = 7
# episode = 5600, total_steps = 7
# episode = 5800, total_steps = 7
# episode = 6000, total_steps = 7
# episode = 6200, total_steps = 7
# episode = 6400, total_steps = 8
# episode = 6600, total_steps = 8
# episode = 6800, total_steps = 13
# episode = 7000, total_steps = 7
# episode = 7200, total_steps = 10
# episode = 7400, total_steps = 12
# episode = 7600, total_steps = 9
# episode = 7800, total_steps = 7
# episode = 8000, total_steps = 8
# episode = 8200, total_steps = 7
# episode = 8400, total_steps = 7
# episode = 8600, total_steps = 9
# episode = 8800, total_steps = 10
# episode = 9000, total_steps = 7
# episode = 9200, total_steps = 9
# episode = 9400, total_steps = 9
# episode = 9600, total_steps = 7
# episode = 9800, total_steps = 7

# %%
path = solver.get_paths()
ani = maze_generator.display(startPositions, goalPositions, path, animate=True)
ani.save('test_v1.gif', writer='pillow')

# %%
def transform(vector_or_number, base, forward=True):
    if forward:
        # Forward transformation: vector -> number
        # if isinstance(vector_or_number, list):
            decimal_value = 0
            power = len(vector_or_number) - 1
            for digit in vector_or_number:
                decimal_value += digit * (base ** power)
                power -= 1
            return int(decimal_value)
        # else:
        #     raise ValueError("Input must be a list for forward transformation.")
    else:
        # Backward transformation: number -> vector
        if isinstance(vector_or_number, int):
            result_vector = []
            number = vector_or_number
            while number > 0:
                remainder = number % base
                result_vector.insert(0, remainder)
                number = number // base
            return result_vector
        else:
            raise ValueError("Input must be an integer for backward transformation.")

# %%
class QLearningMazeSolverMultiAgent_V2:
    def __init__(self, maze, startPositions, goalPositions, alpha=0.1, gamma=1, epsilon=0.1, epochs=20000):
        self.maze = maze
        self.startPos = startPositions
        self.goalPos = goalPositions
        self.alpha = alpha  # Learning rate
        self.gamma = gamma  # Discount factor
        self.epsilon = epsilon  # Exploration rate
        self.epochs = epochs  # Number of episodes
        self.height, self.width = maze.shape  # Get maze dimensions
        self.num_agents = len(startPositions)
        #self.q_tables = [np.zeros((self.height, self.width, 5)) for _ in range(self.num_agents)]  # Q-tables for each agent
        self.q_tables = [np.zeros((self.height**self.num_agents, self.width**self.num_agents, 5)) for _ in range(self.num_agents)]  # Q-tables for each agent
        self.MAX_STEPS = 10000
        self.MAX_STEPS_final = 500



    def state_transform(self, state):
        vector1 = [item[0] for item in state]
        vector2 = [item[1] for item in state]
        state_2d = (transform(vector1, self.num_agents), transform(vector2, self.num_agents))
        return state_2d


    def greedy_policy(self, state, agent_id):
        q_values = self.q_tables[agent_id][state[0], state[1]]
        max_q_value = np.max(q_values)
        # Find indices of actions with maximum Q-value
        # greedy_actions = [i for i, q_value in enumerate(
        #     q_values) if q_value == max_q_value]
        # Find indices of actions with maximum Q-value
        greedy_actions = np.where(q_values == max_q_value)[0]        
        # If there are multiple greedy actions, randomly select one
        action = np.random.choice(greedy_actions)
        #action = np.argmax(q_values)
        return action

    def eps_greedy_policy(self, state, agent_id, epsilon=None):
        if epsilon:
            eps_greedy = epsilon
        else:
            eps_greedy = self.epsilon
        if np.random.uniform(0, 1) < eps_greedy:
            return np.random.randint(0, 5)  # Random action (exploration)
        else:
            return self.greedy_policy(state, agent_id)


    def choose_action(self, state, agent_id):
        return self.eps_greedy_policy(state, agent_id)

    def update_q_table(self, state, action, reward, next_state, agent_id):
        self.q_tables[agent_id][state[0], state[1], action] += self.alpha * (
            reward + self.gamma * np.max(self.q_tables[agent_id][next_state[0], next_state[1]]) - self.q_tables[agent_id][state[0], state[1], action]
        )

    def solve_maze(self):
        episode_steps = []
        for ep in range(self.epochs):
            total_steps = 0
            agents_at_goals = np.zeros((self.num_agents,1))  # Keep track of agents at their respective goals
            total_steps = 0
            state = self.startPos.copy()
            while total_steps <= self.MAX_STEPS:
                total_steps += 1
                next_state = state.copy()  # Make a copy of the current state
                for agent_id in range(self.num_agents):
                    # Check if the agent reached its goal
                    if state[agent_id] == self.goalPos[agent_id]:
                       agents_at_goals[agent_id] = 1
                    else:
                        # convert state to state_2d
                        state_2d = self.state_transform(state)
                        action = self.choose_action(state_2d, agent_id)
                        next_state, reward = self.take_action(state, action, agent_id)
                        #print('====================')
                        #print(next_state[agent_id])
                        # convert next_state to next_state_2d
                        next_state_2d = self.state_transform(next_state)
                        self.update_q_table(state_2d, action, reward, next_state_2d, agent_id)
                        state = next_state
                                        
                # Check if all agents reached their goals
                if np.sum(agents_at_goals) == len(self.startPos):
                    #print(f"Episode {ep}: All agents reached their goals.")
                    break  # Stop the episode if all agents reached their goals
                    
            if ep % 200 == 0:
                print('episode = {}, total_steps = {}'.format(ep, total_steps))

            episode_steps.append(total_steps)  # Save total steps for the current episode        
                
        return episode_steps

    def take_action(self, state, action, agent_id):
        actions = [(0, -1), (0, 1), (-1, 0), (1, 0), (0,0)]  # Possible actions: up, down, left, right
        next_state = state.copy()
        next_state[agent_id] = (state[agent_id][0] + actions[action][0], state[agent_id][1] + actions[action][1])
        
        # Ensure next state is within grid boundaries
        next_state[agent_id] = (max(0, min(self.height - 1, next_state[agent_id][0])),
                    max(0, min(self.width - 1, next_state[agent_id][1])))        
        
        reward = 0
        # if state[agent_id] == self.goalPos[agent_id]:
        #     if next_state[agent_id] == self.goalPos[agent_id]:
        #         reward += 0
        #     else:
        #         reward += -100
        
        if  self.maze[next_state[agent_id][0], next_state[agent_id][1]] == 1:  # If next position is a wall, keep the next state the same as the current state
            next_state[agent_id] = state[agent_id]
            reward += -1
        elif any(next_state[agent_id] == state[i] for i in range(len(state)) if i != agent_id):
            next_state[agent_id] = state[agent_id]
            reward += -1
        elif next_state[agent_id] == self.goalPos[agent_id]:
            if state[agent_id] == self.goalPos[agent_id]:
                reward += 0
            else:
                reward += 10  # Reward: 10 for reaching the goal
            done = True  # Episode terminates
        else:   
            reward += -1  # Reward: -1 for every movement
            done = False  # Episode continues

        if state[agent_id] == self.goalPos[agent_id]: # do nothing if reach the goal
            reward = 0
            next_state[agent_id] = state[agent_id]
        
        return next_state, reward

    def get_paths(self):
        paths = [[] for _ in range(self.num_agents)]  # Initialize empty paths for each agent
        states = self.startPos[:]  # Initialize states for each agent
        for agent_id in range(self.num_agents):
            paths[agent_id].append(states[agent_id])
        # Continue until all agents reach their goals
        steps = 0
        use_eps_greedy = False
        while not all(state == goal for state, goal in zip(states, self.goalPos)):
            steps += 1
            state_change = np.zeros((self.num_agents,1))
            for agent_id in range(self.num_agents):
                state_2d = self.state_transform(states)
                if use_eps_greedy:
                    action = self.eps_greedy_policy(state_2d, agent_id)  # Choose action for the agent
                else:
                     action = self.greedy_policy(state_2d, agent_id)  # Choose action for the agent
                next_state, _ = self.take_action(states, action, agent_id)  # Take action
                paths[agent_id].append(next_state[agent_id])  # Append next state to the path
                if not next_state[agent_id] == states[agent_id]:
                    state_change[agent_id] = 1
                states = next_state  # Update state for the next iteration

            if np.sum(state_change) == 0:
                use_eps_greedy = False


            if steps == self.MAX_STEPS_final:
                print('max steps reached')
                break
        
        return paths

# %%
startPositions = [(0, 0), (width-1, 0)]
goalPositions = [(height-1, width-1), (0, height-1)]
# startPositions = [(0, 0)]
# goalPositions = [(height-1, width-1)]
# goalPositions = [(4, 4),  (0, height-1), (0, height-2), (height-3,0),(4,11),(6,9)]
maze_generator.display(startPositions, goalPositions)

# %%
solver.num_agents
# Out:
# 1

# %%
# Create an instance of the solver
solver = QLearningMazeSolverMultiAgent_V2(maze_generator.grid, startPositions, goalPositions, epochs=5000)

# Solve the maze
episode_steps = solver.solve_maze()
# Out:
# episode = 0, total_steps = 99
# episode = 200, total_steps = 14
# episode = 400, total_steps = 9
# episode = 600, total_steps = 13
# episode = 800, total_steps = 14
# episode = 1000, total_steps = 20
# episode = 1200, total_steps = 23
# episode = 1400, total_steps = 30
# episode = 1600, total_steps = 10
# episode = 1800, total_steps = 11
# episode = 2000, total_steps = 9
# episode = 2200, total_steps = 11
# episode = 2400, total_steps = 36
# episode = 2600, total_steps = 11
# episode = 2800, total_steps = 26
# episode = 3000, total_steps = 16
# episode = 3200, total_steps = 14
# episode = 3400, total_steps = 11
# episode = 3600, total_steps = 10
# episode = 3800, total_steps = 12
# episode = 4000, total_steps = 13
# episode = 4200, total_steps = 43
# episode = 4400, total_steps = 17
# episode = 4600, total_steps = 14
# episode = 4800, total_steps = 11

# %%
path = solver.get_paths()
ani = maze_generator.display(startPositions, goalPositions, path, animate=True)
ani.save('test_v2.gif', writer='pillow')

# %%
class QLearningMazeSolverMultiAgent_v3:
    def __init__(self, maze, startPositions, goalPositions, alpha=0.1, gamma=1, epsilon=0.1, epochs=20000):
        self.maze = maze
        self.startPos = startPositions
        self.goalPos = goalPositions
        self.alpha = alpha  # Learning rate
        self.gamma = gamma  # Discount factor
        self.epsilon = epsilon  # Exploration rate
        self.epochs = epochs  # Number of episodes
        self.height, self.width = maze.shape  # Get maze dimensions
        self.num_agents = len(startPositions)
        #self.q_tables = [np.zeros((self.height, self.width, 5)) for _ in range(self.num_agents)]  # Q-tables for each agent
        self.q_table = np.zeros((self.height**self.num_agents, self.width**self.num_agents, 5**self.num_agents))-100 # Q-tables
        self.MAX_STEPS = 10000
        self.MAX_STEPS_final = 500



    def state_transform(self, state):
        vector1 = [item[0] for item in state]
        vector2 = [item[1] for item in state]
        state_2d = (transform(vector1, self.num_agents), transform(vector2, self.num_agents))
        return state_2d

    def greedy_policy(self, state):
        q_values = self.q_table[state[0], state[1]]
        max_q_value = np.max(q_values)
        # Find indices of actions with maximum Q-value
        greedy_actions = [i for i, q_value in enumerate(
            q_values) if q_value == max_q_value]
        # If there are multiple greedy actions, randomly select one
        action = np.random.choice(greedy_actions)
        #action = np.argmax(q_values)
        return action

    def eps_greedy_policy(self, state):
        if np.random.uniform(0, 1) < self.epsilon:
            return np.random.randint(0, 5**self.num_agents)  # Random action (exploration)
        else:
            return self.greedy_policy(state)


    def choose_action(self, state):
        return self.eps_greedy_policy(state)

    def update_q_table(self, state, action, reward, next_state):
        self.q_table[state[0], state[1], action] += self.alpha * (reward + self.gamma * np.max(self.q_table[next_state[0], next_state[1]]) - self.q_table[state[0], state[1], action])


    def solve_maze(self):
        episode_steps = []
        for ep in range(self.epochs):
            total_steps = 0
            agents_at_goals = np.zeros((self.num_agents,1))  # Keep track of agents at their respective goals
            total_steps = 0
            state = self.startPos.copy()
            while total_steps <= self.MAX_STEPS:
                total_steps += 1
                next_state = state.copy()  # Make a copy of the current state
                # convert state to state_2d
                state_2d = self.state_transform(state)
                action_id = self.choose_action(state_2d)
                action = np.unravel_index(action_id, (5,)*self.num_agents)

                # take action if action is valid
                next_state, reward = self.take_action(state, action)
                #print('====================')
                #print(next_state[agent_id])
                # convert next_state to next_state_2d
                next_state_2d = self.state_transform(next_state)
                self.update_q_table(state_2d, action, reward, next_state_2d)
                state = next_state

                for agent_id in range(self.num_agents):
                    # Check if the agent reached its goal
                    if state[agent_id] == self.goalPos[agent_id]:
                       agents_at_goals[agent_id] = 1
                                        
                # Check if all agents reached their goals
                if np.sum(agents_at_goals) == len(self.startPos):
                    #print(f"Episode {ep}: All agents reached their goals.")
                    break  # Stop the episode if all agents reached their goals
                    
            # if ep % 200 == 0:
            #     print('episode = {}, total_steps = {}'.format(ep, total_steps))
            print('episode = {}, total_steps = {}'.format(ep, total_steps))
            episode_steps.append(total_steps)  # Save total steps for the current episode        
                
        return episode_steps

    def take_action(self, state, action):
        actions = [(0, -1), (0, 1), (-1, 0), (1, 0), (0,0)]  # Possible actions: up, down, left, right
        next_state = state.copy()
        reward = 0
        for agent_id in range(self.num_agents):
            next_state[agent_id] = (state[agent_id][0] + actions[action[agent_id]][0], state[agent_id][1] + actions[action[agent_id]][1])
        
            # Ensure next state is within grid boundaries
            next_state[agent_id] = (max(0, min(self.height - 1, next_state[agent_id][0])),
                        max(0, min(self.width - 1, next_state[agent_id][1])))        
            
            
            if  self.maze[next_state[agent_id][0], next_state[agent_id][1]] == 1:  # If next position is a wall, keep the next state the same as the current state
                next_state[agent_id] = state[agent_id]
                reward += -10
            elif any(next_state[agent_id] == next_state[i] for i in range(len(state)) if i != agent_id):
                next_state[agent_id] = state[agent_id]
                reward += -10
            elif next_state[agent_id] == self.goalPos[agent_id]:
                if state[agent_id] == self.goalPos[agent_id]:
                    reward += -1
                else:
                    reward += 10  # Reward: 10 for reaching the goal
            else:   
                reward += -1  # Reward: -1 for every movement

            if state[agent_id] == self.goalPos[agent_id]: # do nothing if reach the goal
                reward += 0
                next_state[agent_id] = state[agent_id]
        
        return next_state, reward

    def get_paths(self):
        paths = [[] for _ in range(self.num_agents)]  # Initialize empty paths for each agent
        states = self.startPos[:]  # Initialize states for each agent
        for agent_id in range(self.num_agents):
            paths[agent_id].append(states[agent_id])
        # Continue until all agents reach their goals
        steps = 0
        use_eps_greedy = False
        while not all(state == goal for state, goal in zip(states, self.goalPos)):
            steps += 1
            state_change = np.zeros((self.num_agents,1))
            state_2d = self.state_transform(states)
            if use_eps_greedy:
                action_id = self.eps_greedy_policy(state_2d)  # Choose action for the agent
            else:
                action_id = self.greedy_policy(state_2d)  # Choose action for the agent
            action = np.unravel_index(action_id, (5,)*self.num_agents)
            next_state, _ = self.take_action(states, action)  # Take action
            for agent_id in range(self.num_agents):
                paths[agent_id].append(next_state[agent_id])  # Append next state to the path
                if not next_state[agent_id] == states[agent_id]:
                    state_change[agent_id] = 1
            states = next_state  # Update state for the next iteration

            # if np.sum(state_change) == 0:
            #     use_eps_greedy = True


            if steps == self.MAX_STEPS_final:
                print('max steps reached')
                break
        
        return paths

# %%
# Create an instance of the solver
solver = QLearningMazeSolverMultiAgent_v3(maze_generator.grid, startPositions, goalPositions, epochs=20000)

# Solve the maze
episode_steps = solver.solve_maze()
# Out:
# episode = 0, total_steps = 79
# episode = 1, total_steps = 34
# episode = 2, total_steps = 172
# episode = 3, total_steps = 39
# episode = 4, total_steps = 84
# episode = 5, total_steps = 47
# episode = 6, total_steps = 44
# episode = 7, total_steps = 76
# episode = 8, total_steps = 98
# episode = 9, total_steps = 73
# episode = 10, total_steps = 115
# episode = 11, total_steps = 58
# episode = 12, total_steps = 126
# episode = 13, total_steps = 56
# episode = 14, total_steps = 52
# episode = 15, total_steps = 159
# episode = 16, total_steps = 54
# episode = 17, total_steps = 106
# episode = 18, total_steps = 53
# episode = 19, total_steps = 130
# episode = 20, total_steps = 94
# episode = 21, total_steps = 49
# episode = 22, total_steps = 46
# episode = 23, total_steps = 32
# episode = 24, total_steps = 60
# episode = 25, total_steps = 25
# episode = 26, total_steps = 19
# episode = 27, total_steps = 26
# episode = 28, total_steps = 89
# episode = 29, total_steps = 70
# episode = 30, total_steps = 117
# episode = 31, total_steps = 87
# episode = 32, total_steps = 25
# episode = 33, total_steps = 16
# episode = 34, total_steps = 34
# episode = 35, total_steps = 79
# episode = 36, total_steps = 56
# episode = 37, total_steps = 82
# episode = 38, total_steps = 47
# episode = 39, total_steps = 120
# episode = 40, total_steps = 74
# episode = 41, total_steps = 58
# episode = 42, total_steps = 60
# episode = 43, total_steps = 55
# episode = 44, total_steps = 104
# episode = 45, total_steps = 64
# episode = 46, total_steps = 43
# episode = 47, total_steps = 59
# episode = 48, total_steps = 49
# episode = 49, total_steps = 35
# episode = 50, total_steps = 71
# episode = 51, total_steps = 105
# episode = 52, total_steps = 77
# episode = 53, total_steps = 52
# episode = 54, total_steps = 65
# episode = 55, total_steps = 54
# episode = 56, total_steps = 48
# episode = 57, total_steps = 31
# episode = 58, total_steps = 36
# episode = 59, total_steps = 71
# episode = 60, total_steps = 37
# episode = 61, total_steps = 47
# episode = 62, total_steps = 52
# episode = 63, total_steps = 82
# episode = 64, total_steps = 49
# episode = 65, total_steps = 29
# episode = 66, total_steps = 25
# episode = 67, total_steps = 99
# episode = 68, total_steps = 67
# episode = 69, total_steps = 68
# episode = 70, total_steps = 54
# episode = 71, total_steps = 76
# episode = 72, total_steps = 55
# episode = 73, total_steps = 45
# episode = 74, total_steps = 79
# episode = 75, total_steps = 123
# episode = 76, total_steps = 28
# episode = 77, total_steps = 59
# episode = 78, total_steps = 60
# episode = 79, total_steps = 61
# episode = 80, total_steps = 36
# episode = 81, total_steps = 28
# episode = 82, total_steps = 55
# episode = 83, total_steps = 22
# episode = 84, total_steps = 88
# episode = 85, total_steps = 35
# episode = 86, total_steps = 57
# episode = 87, total_steps = 100
# episode = 88, total_steps = 162
# episode = 89, total_steps = 47
# episode = 90, total_steps = 45
# episode = 91, total_steps = 37
# episode = 92, total_steps = 56
# episode = 93, total_steps = 46
# episode = 94, total_steps = 32
# episode = 95, total_steps = 65
# episode = 96, total_steps = 39
# episode = 97, total_steps = 12
# episode = 98, total_steps = 38
# episode = 99, total_steps = 79
# episode = 100, total_steps = 66
# episode = 101, total_steps = 65
# episode = 102, total_steps = 38
# episode = 103, total_steps = 59
# episode = 104, total_steps = 20
# episode = 105, total_steps = 46
# episode = 106, total_steps = 53
# episode = 107, total_steps = 55
# episode = 108, total_steps = 46
# episode = 109, total_steps = 57
# episode = 110, total_steps = 48
# episode = 111, total_steps = 38
# episode = 112, total_steps = 47
# episode = 113, total_steps = 56
# episode = 114, total_steps = 38
# episode = 115, total_steps = 165
# episode = 116, total_steps = 92
# episode = 117, total_steps = 58
# episode = 118, total_steps = 64
# episode = 119, total_steps = 32
# episode = 120, total_steps = 40
# episode = 121, total_steps = 27
# episode = 122, total_steps = 29
# episode = 123, total_steps = 67
# episode = 124, total_steps = 66
# episode = 125, total_steps = 48
# episode = 126, total_steps = 56
# episode = 127, total_steps = 39
# episode = 128, total_steps = 28
# episode = 129, total_steps = 32
# episode = 130, total_steps = 80
# episode = 131, total_steps = 52
# episode = 132, total_steps = 50
# episode = 133, total_steps = 124
# episode = 134, total_steps = 39
# episode = 135, total_steps = 52
# episode = 136, total_steps = 113
# episode = 137, total_steps = 33
# episode = 138, total_steps = 26
# episode = 139, total_steps = 32
# episode = 140, total_steps = 42
# episode = 141, total_steps = 45
# episode = 142, total_steps = 103
# episode = 143, total_steps = 18
# episode = 144, total_steps = 18
# episode = 145, total_steps = 15
# episode = 146, total_steps = 64
# episode = 147, total_steps = 15
# episode = 148, total_steps = 33
# episode = 149, total_steps = 50
# episode = 150, total_steps = 31
# episode = 151, total_steps = 33
# episode = 152, total_steps = 79
# episode = 153, total_steps = 31
# episode = 154, total_steps = 39
# episode = 155, total_steps = 96
# episode = 156, total_steps = 81
# episode = 157, total_steps = 85
# episode = 158, total_steps = 36
# episode = 159, total_steps = 52
# episode = 160, total_steps = 92
# episode = 161, total_steps = 36
# episode = 162, total_steps = 27
# episode = 163, total_steps = 29
# episode = 164, total_steps = 36
# episode = 165, total_steps = 110
# episode = 166, total_steps = 32
# episode = 167, total_steps = 45
# episode = 477, total_steps = 36
# episode = 478, total_steps = 39
# episode = 479, total_steps = 87
# episode = 480, total_steps = 34
# episode = 481, total_steps = 49
# episode = 482, total_steps = 70
# episode = 483, total_steps = 63
# episode = 484, total_steps = 61
# episode = 485, total_steps = 80
# episode = 486, total_steps = 97
# episode = 487, total_steps = 83
# episode = 488, total_steps = 31
# episode = 489, total_steps = 20
# episode = 490, total_steps = 117
# episode = 491, total_steps = 50
# episode = 492, total_steps = 14
# episode = 493, total_steps = 36
# episode = 494, total_steps = 22
# episode = 495, total_steps = 84
# episode = 496, total_steps = 53
# episode = 497, total_steps = 34
# episode = 498, total_steps = 54
# episode = 499, total_steps = 36
# episode = 500, total_steps = 25
# episode = 501, total_steps = 92
# episode = 502, total_steps = 67
# episode = 503, total_steps = 57
# episode = 504, total_steps = 56
# episode = 505, total_steps = 30
# episode = 506, total_steps = 33
# episode = 507, total_steps = 29
# episode = 508, total_steps = 59
# episode = 509, total_steps = 28
# episode = 510, total_steps = 30
# episode = 511, total_steps = 19
# episode = 512, total_steps = 39
# episode = 513, total_steps = 47
# episode = 514, total_steps = 30
# episode = 515, total_steps = 58
# episode = 516, total_steps = 75
# episode = 517, total_steps = 31
# episode = 518, total_steps = 51
# episode = 519, total_steps = 147
# episode = 520, total_steps = 39
# episode = 521, total_steps = 41
# episode = 522, total_steps = 37
# episode = 523, total_steps = 36
# episode = 524, total_steps = 86
# episode = 525, total_steps = 49
# episode = 526, total_steps = 64
# episode = 527, total_steps = 23
# episode = 528, total_steps = 48
# episode = 529, total_steps = 40
# episode = 530, total_steps = 26
# episode = 531, total_steps = 29
# episode = 532, total_steps = 113
# episode = 533, total_steps = 22
# episode = 534, total_steps = 22
# episode = 535, total_steps = 36
# episode = 536, total_steps = 28
# episode = 537, total_steps = 87
# episode = 538, total_steps = 34
# episode = 539, total_steps = 68
# episode = 540, total_steps = 66
# episode = 541, total_steps = 29
# episode = 542, total_steps = 30
# episode = 543, total_steps = 31
# episode = 544, total_steps = 44
# episode = 545, total_steps = 50
# episode = 546, total_steps = 45
# episode = 547, total_steps = 21
# episode = 548, total_steps = 38
# episode = 549, total_steps = 39
# episode = 550, total_steps = 55
# episode = 551, total_steps = 60
# episode = 552, total_steps = 117
# episode = 553, total_steps = 60
# episode = 554, total_steps = 83
# episode = 555, total_steps = 107
# episode = 556, total_steps = 51
# episode = 557, total_steps = 89
# episode = 558, total_steps = 28
# episode = 559, total_steps = 86
# episode = 560, total_steps = 69
# episode = 561, total_steps = 30
# episode = 562, total_steps = 21
# episode = 563, total_steps = 26
# episode = 564, total_steps = 28
# episode = 565, total_steps = 174
# episode = 566, total_steps = 82
# episode = 567, total_steps = 57
# episode = 568, total_steps = 24
# episode = 569, total_steps = 54
# episode = 570, total_steps = 48
# episode = 571, total_steps = 56
# episode = 572, total_steps = 37
# episode = 573, total_steps = 60
# episode = 574, total_steps = 68
# episode = 575, total_steps = 54
# episode = 576, total_steps = 75
# episode = 577, total_steps = 25
# episode = 578, total_steps = 60
# episode = 579, total_steps = 31
# episode = 580, total_steps = 55
# episode = 581, total_steps = 72
# episode = 582, total_steps = 113
# episode = 583, total_steps = 56
# episode = 584, total_steps = 20
# episode = 585, total_steps = 24
# episode = 586, total_steps = 33
# episode = 587, total_steps = 48
# episode = 588, total_steps = 157
# episode = 589, total_steps = 60
# episode = 590, total_steps = 26
# episode = 591, total_steps = 113
# episode = 592, total_steps = 61
# episode = 593, total_steps = 62
# episode = 594, total_steps = 48
# episode = 595, total_steps = 65
# episode = 596, total_steps = 24
# episode = 597, total_steps = 48
# episode = 598, total_steps = 95
# episode = 599, total_steps = 36
# episode = 600, total_steps = 91
# episode = 601, total_steps = 24
# episode = 602, total_steps = 66
# episode = 603, total_steps = 74
# episode = 604, total_steps = 84
# episode = 605, total_steps = 93
# episode = 606, total_steps = 28
# episode = 607, total_steps = 32
# episode = 608, total_steps = 28
# episode = 609, total_steps = 20
# episode = 610, total_steps = 70
# episode = 611, total_steps = 90
# episode = 612, total_steps = 28
# episode = 613, total_steps = 68
# episode = 614, total_steps = 55
# episode = 615, total_steps = 110
# episode = 616, total_steps = 34
# episode = 617, total_steps = 114
# episode = 618, total_steps = 49
# episode = 619, total_steps = 71
# episode = 620, total_steps = 77
# episode = 621, total_steps = 23
# episode = 622, total_steps = 27
# episode = 623, total_steps = 19
# episode = 624, total_steps = 42
# episode = 625, total_steps = 22
# episode = 626, total_steps = 36
# episode = 627, total_steps = 115
# episode = 628, total_steps = 51
# episode = 629, total_steps = 24
# episode = 630, total_steps = 178
# episode = 631, total_steps = 76
# episode = 632, total_steps = 68
# episode = 633, total_steps = 24
# episode = 634, total_steps = 67
# episode = 635, total_steps = 43
# episode = 636, total_steps = 47
# episode = 637, total_steps = 117
# episode = 638, total_steps = 67
# episode = 639, total_steps = 159
# episode = 640, total_steps = 58
# episode = 641, total_steps = 29
# episode = 642, total_steps = 49
# episode = 643, total_steps = 47
# episode = 644, total_steps = 44
# episode = 645, total_steps = 31
# episode = 646, total_steps = 39
# episode = 647, total_steps = 50
# episode = 648, total_steps = 37
# episode = 649, total_steps = 85
# episode = 650, total_steps = 47
# episode = 651, total_steps = 37
# episode = 652, total_steps = 28
# episode = 653, total_steps = 53
# episode = 654, total_steps = 62
# episode = 655, total_steps = 75
# episode = 656, total_steps = 37
# episode = 657, total_steps = 81
# episode = 658, total_steps = 31
# episode = 659, total_steps = 88
# episode = 660, total_steps = 20
# episode = 661, total_steps = 20
# episode = 662, total_steps = 38
# episode = 663, total_steps = 20
# episode = 664, total_steps = 18
# episode = 665, total_steps = 57
# episode = 666, total_steps = 104
# episode = 667, total_steps = 52
# episode = 668, total_steps = 46
# episode = 669, total_steps = 81
# episode = 670, total_steps = 53
# episode = 671, total_steps = 76
# episode = 672, total_steps = 74
# episode = 673, total_steps = 79
# episode = 674, total_steps = 68
# episode = 675, total_steps = 41
# episode = 676, total_steps = 37
# episode = 677, total_steps = 28
# episode = 678, total_steps = 63
# episode = 679, total_steps = 46
# episode = 680, total_steps = 33
# episode = 681, total_steps = 23
# episode = 682, total_steps = 93
# episode = 683, total_steps = 47
# episode = 684, total_steps = 103
# episode = 685, total_steps = 119
# episode = 686, total_steps = 53
# episode = 687, total_steps = 100
# episode = 688, total_steps = 34
# episode = 689, total_steps = 92
# episode = 690, total_steps = 42
# episode = 691, total_steps = 95
# episode = 692, total_steps = 27
# episode = 693, total_steps = 53
# episode = 694, total_steps = 33
# episode = 695, total_steps = 53
# episode = 696, total_steps = 50
# episode = 697, total_steps = 31
# episode = 698, total_steps = 27
# episode = 699, total_steps = 72
# episode = 700, total_steps = 108
# episode = 701, total_steps = 177
# episode = 702, total_steps = 112
# episode = 703, total_steps = 87
# episode = 704, total_steps = 32
# episode = 705, total_steps = 38
# episode = 706, total_steps = 68
# episode = 707, total_steps = 28
# episode = 708, total_steps = 38
# episode = 709, total_steps = 43
# episode = 710, total_steps = 38
# episode = 711, total_steps = 68
# episode = 712, total_steps = 37
# episode = 713, total_steps = 118
# episode = 714, total_steps = 53
# episode = 715, total_steps = 17
# episode = 716, total_steps = 33
# episode = 717, total_steps = 44
# episode = 718, total_steps = 75
# episode = 719, total_steps = 22
# episode = 720, total_steps = 55
# episode = 721, total_steps = 34
# episode = 722, total_steps = 51
# episode = 723, total_steps = 20
# episode = 724, total_steps = 81
# episode = 725, total_steps = 38
# episode = 726, total_steps = 27
# episode = 727, total_steps = 74
# episode = 728, total_steps = 51
# episode = 729, total_steps = 42
# episode = 730, total_steps = 64
# episode = 731, total_steps = 40
# episode = 732, total_steps = 126
# episode = 733, total_steps = 14
# episode = 734, total_steps = 30
# episode = 735, total_steps = 36
# episode = 736, total_steps = 42
# episode = 737, total_steps = 85
# episode = 738, total_steps = 23
# episode = 739, total_steps = 223
# episode = 740, total_steps = 49
# episode = 741, total_steps = 27
# episode = 742, total_steps = 99
# episode = 743, total_steps = 17
# episode = 744, total_steps = 64
# episode = 745, total_steps = 93
# episode = 746, total_steps = 17
# episode = 747, total_steps = 56
# episode = 748, total_steps = 31
# episode = 749, total_steps = 118
# episode = 750, total_steps = 32
# episode = 751, total_steps = 20
# episode = 752, total_steps = 37
# episode = 753, total_steps = 51
# episode = 754, total_steps = 123
# episode = 755, total_steps = 54
# episode = 756, total_steps = 30
# episode = 757, total_steps = 43
# episode = 758, total_steps = 132
# episode = 759, total_steps = 47
# episode = 760, total_steps = 14
# episode = 761, total_steps = 127
# episode = 762, total_steps = 28
# episode = 763, total_steps = 76
# episode = 764, total_steps = 35
# episode = 765, total_steps = 50
# episode = 766, total_steps = 76
# episode = 767, total_steps = 51
# episode = 768, total_steps = 90
# episode = 769, total_steps = 85
# episode = 770, total_steps = 140
# episode = 771, total_steps = 32
# episode = 772, total_steps = 29
# episode = 773, total_steps = 84
# episode = 774, total_steps = 63
# episode = 775, total_steps = 77
# episode = 776, total_steps = 65
# episode = 777, total_steps = 64
# episode = 778, total_steps = 46
# episode = 779, total_steps = 103
# episode = 780, total_steps = 38
# episode = 781, total_steps = 59
# episode = 782, total_steps = 73
# episode = 783, total_steps = 29
# episode = 784, total_steps = 35
# episode = 785, total_steps = 41
# episode = 786, total_steps = 34
# episode = 787, total_steps = 32
# episode = 788, total_steps = 57
# episode = 789, total_steps = 34
# episode = 790, total_steps = 31
# episode = 791, total_steps = 61
# episode = 792, total_steps = 34
# episode = 793, total_steps = 126
# episode = 794, total_steps = 44
# episode = 795, total_steps = 21
# episode = 796, total_steps = 41
# episode = 797, total_steps = 52
# episode = 798, total_steps = 50
# episode = 799, total_steps = 87
# episode = 800, total_steps = 107
# episode = 801, total_steps = 92
# episode = 802, total_steps = 38
# episode = 803, total_steps = 38
# episode = 804, total_steps = 32
# episode = 805, total_steps = 21
# episode = 806, total_steps = 45
# episode = 807, total_steps = 26
# episode = 808, total_steps = 11
# episode = 809, total_steps = 112
# episode = 810, total_steps = 55
# episode = 811, total_steps = 32
# episode = 812, total_steps = 63
# episode = 813, total_steps = 71
# episode = 814, total_steps = 31
# episode = 815, total_steps = 39
# episode = 816, total_steps = 35
# episode = 817, total_steps = 94
# episode = 818, total_steps = 17
# episode = 819, total_steps = 63
# episode = 820, total_steps = 75
# episode = 821, total_steps = 45
# episode = 822, total_steps = 44
# episode = 823, total_steps = 36
# episode = 824, total_steps = 66
# episode = 825, total_steps = 33
# episode = 826, total_steps = 100
# episode = 827, total_steps = 110
# episode = 828, total_steps = 58
# episode = 829, total_steps = 30
# episode = 830, total_steps = 87
# episode = 831, total_steps = 55
# episode = 832, total_steps = 73
# episode = 833, total_steps = 98
# episode = 834, total_steps = 86
# episode = 835, total_steps = 18
# episode = 836, total_steps = 44
# episode = 837, total_steps = 32
# episode = 838, total_steps = 32
# episode = 839, total_steps = 29
# episode = 840, total_steps = 71
# episode = 841, total_steps = 67
# episode = 842, total_steps = 19
# episode = 843, total_steps = 66
# episode = 844, total_steps = 78
# episode = 845, total_steps = 59
# episode = 846, total_steps = 87
# episode = 847, total_steps = 61
# episode = 848, total_steps = 65
# episode = 849, total_steps = 21
# episode = 850, total_steps = 54
# episode = 851, total_steps = 37
# episode = 852, total_steps = 66
# episode = 853, total_steps = 48
# episode = 854, total_steps = 71
# episode = 855, total_steps = 71
# episode = 856, total_steps = 58
# episode = 857, total_steps = 27
# episode = 858, total_steps = 32
# episode = 859, total_steps = 75
# episode = 860, total_steps = 67
# episode = 861, total_steps = 35
# episode = 862, total_steps = 67
# episode = 863, total_steps = 63
# episode = 864, total_steps = 86
# episode = 865, total_steps = 71
# episode = 866, total_steps = 36
# episode = 867, total_steps = 19
# episode = 868, total_steps = 56
# episode = 869, total_steps = 28
# episode = 870, total_steps = 40
# episode = 871, total_steps = 52
# episode = 872, total_steps = 41
# episode = 873, total_steps = 25
# episode = 874, total_steps = 62
# episode = 875, total_steps = 45
# episode = 876, total_steps = 32
# episode = 877, total_steps = 68
# episode = 878, total_steps = 64
# episode = 879, total_steps = 66
# episode = 880, total_steps = 9
# episode = 881, total_steps = 104
# episode = 882, total_steps = 33
# episode = 883, total_steps = 45
# episode = 884, total_steps = 38
# episode = 885, total_steps = 56
# episode = 886, total_steps = 36
# episode = 887, total_steps = 29
# episode = 888, total_steps = 36
# episode = 992, total_steps = 94
# episode = 993, total_steps = 27
# episode = 994, total_steps = 18
# episode = 995, total_steps = 18
# episode = 996, total_steps = 85
# episode = 997, total_steps = 53
# episode = 998, total_steps = 90
# episode = 999, total_steps = 41
# episode = 1000, total_steps = 41
# episode = 1001, total_steps = 50
# episode = 1002, total_steps = 24
# episode = 1003, total_steps = 51
# episode = 1004, total_steps = 49
# episode = 1005, total_steps = 20
# episode = 1006, total_steps = 94
# episode = 1007, total_steps = 29
# episode = 1008, total_steps = 16
# episode = 1009, total_steps = 19
# episode = 1010, total_steps = 43
# episode = 1011, total_steps = 64
# episode = 1012, total_steps = 25
# episode = 1013, total_steps = 64
# episode = 1014, total_steps = 35
# episode = 1015, total_steps = 90
# episode = 1016, total_steps = 51
# episode = 1017, total_steps = 17
# episode = 1018, total_steps = 18
# episode = 1019, total_steps = 42
# episode = 1020, total_steps = 86
# episode = 1021, total_steps = 35
# episode = 1022, total_steps = 51
# episode = 1023, total_steps = 56
# episode = 1024, total_steps = 42
# episode = 1025, total_steps = 45
# episode = 1026, total_steps = 51
# episode = 1027, total_steps = 98
# episode = 1028, total_steps = 25
# episode = 1029, total_steps = 55
# episode = 1030, total_steps = 23
# episode = 1031, total_steps = 53
# episode = 1032, total_steps = 61
# episode = 1033, total_steps = 106
# episode = 1034, total_steps = 32
# episode = 1035, total_steps = 33
# episode = 1036, total_steps = 20
# episode = 1037, total_steps = 65
# episode = 1038, total_steps = 49
# episode = 1039, total_steps = 17
# episode = 1040, total_steps = 23
# episode = 1041, total_steps = 34
# episode = 1042, total_steps = 44
# episode = 1043, total_steps = 30
# episode = 1044, total_steps = 15
# episode = 1045, total_steps = 87
# episode = 1046, total_steps = 77
# episode = 1047, total_steps = 73
# episode = 1048, total_steps = 111
# episode = 1049, total_steps = 77
# episode = 1050, total_steps = 99
# episode = 1051, total_steps = 57
# episode = 1052, total_steps = 107
# episode = 1053, total_steps = 53
# episode = 1054, total_steps = 47
# episode = 1055, total_steps = 49
# episode = 1056, total_steps = 36
# episode = 1057, total_steps = 38
# episode = 1058, total_steps = 35
# episode = 1059, total_steps = 33
# episode = 1060, total_steps = 75
# episode = 1061, total_steps = 37
# episode = 1062, total_steps = 29
# episode = 1063, total_steps = 34
# episode = 1064, total_steps = 41
# episode = 1065, total_steps = 79
# episode = 1066, total_steps = 44
# episode = 1067, total_steps = 54
# episode = 1068, total_steps = 34
# episode = 1069, total_steps = 23
# episode = 1070, total_steps = 40
# episode = 1071, total_steps = 50
# episode = 1072, total_steps = 26
# episode = 1073, total_steps = 40
# episode = 1074, total_steps = 28
# episode = 1075, total_steps = 17
# episode = 1076, total_steps = 46
# episode = 1077, total_steps = 57
# episode = 1078, total_steps = 66
# episode = 1079, total_steps = 59
# episode = 1080, total_steps = 42
# episode = 1081, total_steps = 30
# episode = 1082, total_steps = 58
# episode = 1083, total_steps = 34
# episode = 1084, total_steps = 30
# episode = 1085, total_steps = 19
# episode = 1086, total_steps = 53
# episode = 1087, total_steps = 48
# episode = 1088, total_steps = 68
# episode = 1089, total_steps = 92
# episode = 1090, total_steps = 16
# episode = 1091, total_steps = 51
# episode = 1092, total_steps = 26
# episode = 1093, total_steps = 83
# episode = 1094, total_steps = 43
# episode = 1095, total_steps = 20
# episode = 1096, total_steps = 23
# episode = 1097, total_steps = 20
# episode = 1098, total_steps = 18
# episode = 1099, total_steps = 29
# episode = 1100, total_steps = 76
# episode = 1101, total_steps = 43
# episode = 1102, total_steps = 59
# episode = 1103, total_steps = 42
# episode = 1104, total_steps = 60
# episode = 1105, total_steps = 58
# episode = 1106, total_steps = 88
# episode = 1107, total_steps = 29
# episode = 1108, total_steps = 46
# episode = 1109, total_steps = 46
# episode = 1110, total_steps = 29
# episode = 1111, total_steps = 36
# episode = 1112, total_steps = 59
# episode = 1113, total_steps = 27
# episode = 1114, total_steps = 64
# episode = 1115, total_steps = 69
# episode = 1116, total_steps = 84
# episode = 1117, total_steps = 95
# episode = 1118, total_steps = 40
# episode = 1119, total_steps = 47
# episode = 1120, total_steps = 28
# episode = 1121, total_steps = 36
# episode = 1122, total_steps = 17
# episode = 1123, total_steps = 38
# episode = 1124, total_steps = 49
# episode = 1125, total_steps = 33
# episode = 1126, total_steps = 49
# episode = 1127, total_steps = 39
# episode = 1128, total_steps = 44
# episode = 1129, total_steps = 82
# episode = 1130, total_steps = 43
# episode = 1131, total_steps = 35
# episode = 1132, total_steps = 71
# episode = 1133, total_steps = 103
# episode = 1134, total_steps = 60
# episode = 1135, total_steps = 54
# episode = 1136, total_steps = 76
# episode = 1137, total_steps = 53
# episode = 1138, total_steps = 70
# episode = 1139, total_steps = 24
# episode = 1140, total_steps = 26
# episode = 1141, total_steps = 43
# episode = 1142, total_steps = 75
# episode = 1143, total_steps = 24
# episode = 1144, total_steps = 28
# episode = 1145, total_steps = 95
# episode = 1146, total_steps = 17
# episode = 1147, total_steps = 26
# episode = 1148, total_steps = 67
# episode = 1149, total_steps = 62
# episode = 1150, total_steps = 125
# episode = 1151, total_steps = 35
# episode = 1152, total_steps = 28
# episode = 1153, total_steps = 77
# episode = 1154, total_steps = 32
# episode = 1155, total_steps = 127
# episode = 1156, total_steps = 66
# episode = 1157, total_steps = 165
# episode = 1158, total_steps = 35
# episode = 1159, total_steps = 101
# episode = 1160, total_steps = 28
# episode = 1161, total_steps = 72
# episode = 1162, total_steps = 20
# episode = 1163, total_steps = 107
# episode = 1164, total_steps = 51
# episode = 1165, total_steps = 23
# episode = 1166, total_steps = 64
# episode = 1167, total_steps = 65
# episode = 1168, total_steps = 82
# episode = 1169, total_steps = 54
# episode = 1170, total_steps = 28
# episode = 1171, total_steps = 116
# episode = 1172, total_steps = 23
# episode = 1173, total_steps = 46
# episode = 1174, total_steps = 69
# episode = 1175, total_steps = 144
# episode = 1176, total_steps = 26
# episode = 1177, total_steps = 41
# episode = 1178, total_steps = 122
# episode = 1179, total_steps = 86
# episode = 1180, total_steps = 36
# episode = 1181, total_steps = 76
# episode = 1182, total_steps = 43
# episode = 1183, total_steps = 27
# episode = 1184, total_steps = 28
# episode = 1185, total_steps = 11
# episode = 1186, total_steps = 71
# episode = 1187, total_steps = 27
# episode = 1188, total_steps = 49
# episode = 1189, total_steps = 83
# episode = 1190, total_steps = 40
# episode = 1191, total_steps = 59
# episode = 1192, total_steps = 40
# episode = 1193, total_steps = 78
# episode = 1194, total_steps = 34
# episode = 1195, total_steps = 67
# episode = 1196, total_steps = 74
# episode = 1197, total_steps = 28
# episode = 1198, total_steps = 17
# episode = 1199, total_steps = 50
# episode = 1200, total_steps = 49
# episode = 1201, total_steps = 17
# episode = 1202, total_steps = 29
# episode = 1203, total_steps = 25
# episode = 1204, total_steps = 35
# episode = 1205, total_steps = 107
# episode = 1206, total_steps = 76
# episode = 1207, total_steps = 45
# episode = 1208, total_steps = 42
# episode = 1209, total_steps = 104
# episode = 1210, total_steps = 72
# episode = 1211, total_steps = 63
# episode = 1212, total_steps = 86
# episode = 1213, total_steps = 79
# episode = 1214, total_steps = 31
# episode = 1215, total_steps = 34
# episode = 1216, total_steps = 78
# episode = 1217, total_steps = 32
# episode = 1218, total_steps = 55
# episode = 1219, total_steps = 37
# episode = 1220, total_steps = 55
# episode = 1221, total_steps = 83
# episode = 1222, total_steps = 44
# episode = 1223, total_steps = 45
# episode = 1224, total_steps = 57
# episode = 1225, total_steps = 27
# episode = 1226, total_steps = 61
# episode = 1227, total_steps = 40
# episode = 1228, total_steps = 39
# episode = 1229, total_steps = 63
# episode = 1230, total_steps = 44
# episode = 1231, total_steps = 27
# episode = 1232, total_steps = 49
# episode = 1233, total_steps = 49
# episode = 1234, total_steps = 25
# episode = 1235, total_steps = 79
# episode = 1236, total_steps = 39
# episode = 1237, total_steps = 12
# episode = 1238, total_steps = 41
# episode = 1239, total_steps = 77
# episode = 1240, total_steps = 44
# episode = 1241, total_steps = 88
# episode = 1242, total_steps = 33
# episode = 1243, total_steps = 47
# episode = 1244, total_steps = 78
# episode = 1245, total_steps = 41
# episode = 1246, total_steps = 82
# episode = 1247, total_steps = 15
# episode = 1248, total_steps = 47
# episode = 1249, total_steps = 77
# episode = 1250, total_steps = 76
# episode = 1251, total_steps = 29
# episode = 1252, total_steps = 190
# episode = 1253, total_steps = 42
# episode = 1254, total_steps = 55
# episode = 1255, total_steps = 47
# episode = 1256, total_steps = 64
# episode = 1257, total_steps = 45
# episode = 1258, total_steps = 52
# episode = 1259, total_steps = 14
# episode = 1260, total_steps = 58
# episode = 1261, total_steps = 63
# episode = 1262, total_steps = 41
# episode = 1263, total_steps = 79
# episode = 1264, total_steps = 32
# episode = 1265, total_steps = 29
# episode = 1266, total_steps = 113
# episode = 1267, total_steps = 42
# episode = 1268, total_steps = 33
# episode = 1269, total_steps = 74
# episode = 1270, total_steps = 63
# episode = 1271, total_steps = 25
# episode = 1272, total_steps = 118
# episode = 1273, total_steps = 30
# episode = 1274, total_steps = 107
# episode = 1275, total_steps = 78
# episode = 1276, total_steps = 66
# episode = 1277, total_steps = 139
# episode = 1278, total_steps = 69
# episode = 1279, total_steps = 54
# episode = 1280, total_steps = 83
# episode = 1281, total_steps = 38
# episode = 1282, total_steps = 33
# episode = 1283, total_steps = 31
# episode = 1284, total_steps = 51
# episode = 1285, total_steps = 29
# episode = 1286, total_steps = 51
# episode = 1287, total_steps = 69
# episode = 1288, total_steps = 28
# episode = 1289, total_steps = 32
# episode = 1290, total_steps = 57
# episode = 1291, total_steps = 54
# episode = 1292, total_steps = 63
# episode = 1293, total_steps = 38
# episode = 1294, total_steps = 29
# episode = 1295, total_steps = 45
# episode = 1296, total_steps = 56
# episode = 1297, total_steps = 39
# episode = 1298, total_steps = 94
# episode = 1299, total_steps = 36
# episode = 1300, total_steps = 18
# episode = 1301, total_steps = 38
# episode = 1302, total_steps = 23
# episode = 1303, total_steps = 56
# episode = 1304, total_steps = 32
# episode = 1305, total_steps = 136
# episode = 1306, total_steps = 20
# episode = 1307, total_steps = 28
# episode = 1308, total_steps = 34
# episode = 1309, total_steps = 33
# episode = 1310, total_steps = 100
# episode = 1311, total_steps = 18
# episode = 1312, total_steps = 39
# episode = 1313, total_steps = 119
# episode = 1314, total_steps = 73
# episode = 1315, total_steps = 92
# episode = 1316, total_steps = 42
# episode = 1317, total_steps = 17
# episode = 1318, total_steps = 32
# episode = 1319, total_steps = 73
# episode = 1320, total_steps = 53
# episode = 1321, total_steps = 28
# episode = 1322, total_steps = 24
# episode = 1323, total_steps = 155
# episode = 1324, total_steps = 21
# episode = 1325, total_steps = 131
# episode = 1326, total_steps = 100
# episode = 1327, total_steps = 61
# episode = 1328, total_steps = 42
# episode = 1329, total_steps = 30
# episode = 1330, total_steps = 23
# episode = 1331, total_steps = 77
# episode = 1332, total_steps = 55
# episode = 1333, total_steps = 20
# episode = 1334, total_steps = 38
# episode = 1335, total_steps = 78
# episode = 1336, total_steps = 46
# episode = 1337, total_steps = 23
# episode = 1338, total_steps = 90
# episode = 1339, total_steps = 32
# episode = 1340, total_steps = 33
# episode = 1341, total_steps = 15
# episode = 1342, total_steps = 32
# episode = 1343, total_steps = 59
# episode = 1344, total_steps = 54
# episode = 1345, total_steps = 81
# episode = 1346, total_steps = 76
# episode = 1347, total_steps = 56
# episode = 1348, total_steps = 25
# episode = 1349, total_steps = 81
# episode = 1350, total_steps = 66
# episode = 1351, total_steps = 45
# episode = 1352, total_steps = 30
# episode = 1353, total_steps = 39
# episode = 1354, total_steps = 89
# episode = 1355, total_steps = 31
# episode = 1356, total_steps = 33
# episode = 1357, total_steps = 55
# episode = 1358, total_steps = 51
# episode = 1359, total_steps = 117
# episode = 1360, total_steps = 35
# episode = 1361, total_steps = 53
# episode = 1362, total_steps = 58
# episode = 1363, total_steps = 81
# episode = 1364, total_steps = 60
# episode = 1365, total_steps = 99
# episode = 1366, total_steps = 41
# episode = 1367, total_steps = 25
# episode = 1368, total_steps = 32
# episode = 1369, total_steps = 70
# episode = 1370, total_steps = 16
# episode = 1371, total_steps = 28
# episode = 1372, total_steps = 47
# episode = 1373, total_steps = 58
# episode = 1374, total_steps = 32
# episode = 1375, total_steps = 105
# episode = 1376, total_steps = 100
# episode = 1377, total_steps = 34
# episode = 1378, total_steps = 73
# episode = 1379, total_steps = 59
# episode = 1380, total_steps = 62
# episode = 1381, total_steps = 24
# episode = 1382, total_steps = 52
# episode = 1383, total_steps = 43
# episode = 1384, total_steps = 68
# episode = 1385, total_steps = 58
# episode = 1386, total_steps = 16
# episode = 1387, total_steps = 21
# episode = 1388, total_steps = 34
# episode = 1389, total_steps = 128
# episode = 1390, total_steps = 100
# episode = 1391, total_steps = 36
# episode = 1392, total_steps = 102
# episode = 1393, total_steps = 27
# episode = 1394, total_steps = 42
# episode = 1395, total_steps = 23
# episode = 1396, total_steps = 34
# episode = 1397, total_steps = 93
# episode = 1398, total_steps = 29
# episode = 1399, total_steps = 46
# episode = 1400, total_steps = 82
# episode = 1401, total_steps = 64
# episode = 1402, total_steps = 30
# episode = 1403, total_steps = 49
# episode = 1404, total_steps = 28
# episode = 1405, total_steps = 59
# episode = 1406, total_steps = 56
# episode = 1407, total_steps = 26
# episode = 1408, total_steps = 50
# episode = 1409, total_steps = 41
# episode = 1410, total_steps = 48
# episode = 1411, total_steps = 34
# episode = 1412, total_steps = 24
# episode = 1413, total_steps = 45
# episode = 1414, total_steps = 56
# episode = 1415, total_steps = 55
# episode = 1416, total_steps = 61
# episode = 1417, total_steps = 20
# episode = 1418, total_steps = 32
# episode = 1419, total_steps = 38
# episode = 1420, total_steps = 106
# episode = 1421, total_steps = 44
# episode = 1422, total_steps = 35
# episode = 1423, total_steps = 49
# episode = 1424, total_steps = 47
# episode = 1425, total_steps = 69
# episode = 1426, total_steps = 50
# episode = 1427, total_steps = 27
# episode = 1428, total_steps = 35
# episode = 1429, total_steps = 75
# episode = 1430, total_steps = 49
# episode = 1431, total_steps = 130
# episode = 1432, total_steps = 89
# episode = 1433, total_steps = 20
# episode = 1434, total_steps = 25
# episode = 1435, total_steps = 145
# episode = 1436, total_steps = 56
# episode = 1437, total_steps = 19
# episode = 1438, total_steps = 58
# episode = 1439, total_steps = 51
# episode = 1440, total_steps = 36
# episode = 1441, total_steps = 29
# episode = 1442, total_steps = 22
# episode = 1443, total_steps = 26
# episode = 1444, total_steps = 23
# episode = 1445, total_steps = 28
# episode = 1446, total_steps = 59
# episode = 1447, total_steps = 128
# episode = 1448, total_steps = 52
# episode = 1449, total_steps = 43
# episode = 1450, total_steps = 15
# episode = 1451, total_steps = 82
# episode = 1452, total_steps = 16
# episode = 1453, total_steps = 59
# episode = 1454, total_steps = 77
# episode = 1455, total_steps = 31
# episode = 1456, total_steps = 34
# episode = 1457, total_steps = 48
# episode = 1458, total_steps = 41
# episode = 1459, total_steps = 16
# episode = 1460, total_steps = 30
# episode = 1461, total_steps = 81
# episode = 1462, total_steps = 50
# episode = 1463, total_steps = 63
# episode = 1464, total_steps = 37
# episode = 1465, total_steps = 64
# episode = 1466, total_steps = 54
# episode = 1467, total_steps = 37
# episode = 1468, total_steps = 77
# episode = 1469, total_steps = 51
# episode = 1470, total_steps = 47
# episode = 1471, total_steps = 99
# episode = 1472, total_steps = 35
# episode = 1473, total_steps = 48
# episode = 1474, total_steps = 60
